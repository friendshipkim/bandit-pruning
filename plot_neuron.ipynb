# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pruning_type = 'neuron'
block_num = 5

# %%
def draw_accuracy_plot(prune_after_accuracy):
    plt.plot(prune_after_accuracy)
    plt.xlabel('Number of heads pruned')
    plt.ylabel('Accuracy after pruning')
    plt.title(algo_name)
    # plt.axis([0, n_heads-1, 0, 1])
    plt.grid(True)
    plt.show()

# %% [markdown]
# # random

# %%
algo_name = 'random'

# %%
result_path = os.path.join('./results', pruning_type, str(block_num), algo_name)
result_path
# Out:
# './results/neuron/5/random'

# %%
prune_order = np.load(os.path.join(result_path, "prune_order.npy"))
prune_after_accuracy = np.load(os.path.join(result_path, "prune_after_accuracy.npy"))

# %%
draw_accuracy_plot(prune_after_accuracy)

# %%
Random = prune_after_accuracy

# %% [markdown]
# # UCB1

# %%
algo_name = 'UCB1'

# %%
result_path = os.path.join('./results', pruning_type, str(block_num), algo_name)
result_path
# Out:
# './results/neuron/5/UCB1'

# %%
counts = np.load(os.path.join(result_path, "counts.npy"))
expected_rewards = np.load(os.path.join(result_path, "expected_rewards.npy"))
prune_order = np.load(os.path.join(result_path, "prune_order.npy"))
prune_after_accuracy = np.load(os.path.join(result_path, "prune_after_accuracy.npy"))

# %%
print("counts:\n {} \n".format(counts))
print("expected_rewards:\n {} \n".format(expected_rewards))
print("prune_order:\n {} \n".format(prune_order))
print("prune_after_accuracy:\n {}".format(prune_after_accuracy))
# Out:
# counts:
#  [3 3 4 ... 3 4 3]
#
# expected_rewards:
#  [0.17568295 0.19391211 0.21279232 ... 0.16787045 0.2108392  0.20693295]
#
# prune_order:
#  [ 514 1150 1259 ... 2903 2998 2291]
#
# prune_after_accuracy:
#  [0.82129394 0.82129394 0.82129394 ... 0.82068263 0.82068263 0.82068263]

# %%
draw_accuracy_plot(prune_after_accuracy)

# %%
UCB1 = prune_after_accuracy

# %% [markdown]
# # EpsilonGreedy

# %%
algo_name = 'EpsilonGreedy'

# %%
result_path = os.path.join('./results', pruning_type, str(block_num), algo_name)
result_path
# Out:
# './results/neuron/5/EpsilonGreedy'

# %%
counts = np.load(os.path.join(result_path, "counts.npy"))
expected_rewards = np.load(os.path.join(result_path, "expected_rewards.npy"))
prune_order = np.load(os.path.join(result_path, "prune_order.npy"))
prune_after_accuracy = np.load(os.path.join(result_path, "prune_after_accuracy.npy"))

# %%
print("counts:\n {} \n".format(counts))
print("expected_rewards:\n {} \n".format(expected_rewards))
print("prune_order:\n {} \n".format(prune_order))
print("prune_after_accuracy:\n {}".format(prune_after_accuracy))
# Out:
# counts:
#  [0 4 4 ... 8 2 7]
#
# expected_rewards:
#  [0.         0.2030267  0.1795892  ... 0.22548763 0.2264642  0.18684366]
#
# prune_order:
#  [ 477 3004   69 ... 2991 3044 3053]
#
# prune_after_accuracy:
#  [0.82098828 0.82098828 0.82098828 ... 0.8208864  0.8208864  0.8208864 ]

# %%
draw_accuracy_plot(prune_after_accuracy)

# %%
EpsilonGreedy = prune_after_accuracy

# %% [markdown]
# # AnnealingEpsilonGreedy

# %%
algo_name = 'AnnealingEpsilonGreedy'

# %%
result_path = os.path.join('./results', pruning_type, str(block_num), algo_name)
result_path
# Out:
# './results/neuron/5/AnnealingEpsilonGreedy'

# %%
counts = np.load(os.path.join(result_path, "counts.npy"))
expected_rewards = np.load(os.path.join(result_path, "expected_rewards.npy"))
prune_order = np.load(os.path.join(result_path, "prune_order.npy"))
prune_after_accuracy = np.load(os.path.join(result_path, "prune_after_accuracy.npy"))

# %%
print("counts:\n {} \n".format(counts))
print("expected_rewards:\n {} \n".format(expected_rewards))
print("prune_order:\n {} \n".format(prune_order))
print("prune_after_accuracy:\n {}".format(prune_after_accuracy))
# Out:
# counts:
#  [ 0  0 12 ... 12  0  1]
#
# expected_rewards:
#  [0.         0.         0.2030267  ... 0.20172461 0.         0.17568295]
#
# prune_order:
#  [2542 1991  356 ... 3065 3066 3070]
#
# prune_after_accuracy:
#  [0.82119205 0.82119205 0.82119205 ... 0.8208864  0.8208864  0.8208864 ]

# %%
draw_accuracy_plot(prune_after_accuracy)

# %%
AnnealingEpsilonGreedy = prune_after_accuracy

# %% [markdown]
# # Softmax

# %%
algo_name = 'Softmax'

# %%
result_path = os.path.join('./results', pruning_type, str(block_num), algo_name)
result_path
# Out:
# './results/neuron/5/Softmax'

# %%
counts = np.load(os.path.join(result_path, "counts.npy"))
expected_rewards = np.load(os.path.join(result_path, "expected_rewards.npy"))
prune_order = np.load(os.path.join(result_path, "prune_order.npy"))
prune_after_accuracy = np.load(os.path.join(result_path, "prune_after_accuracy.npy"))

# %%
print("counts:\n {} \n".format(counts))
print("expected_rewards:\n {} \n".format(expected_rewards))
print("prune_order:\n {} \n".format(prune_order))
print("prune_after_accuracy:\n {}".format(prune_after_accuracy))
# Out:
# counts:
#  [6 4 3 ... 2 6 2]
#
# expected_rewards:
#  [0.14179755 0.13203193 0.10013089 ... 0.1222663  0.11836005 0.1613288 ]
#
# prune_order:
#  [ 359  933  964 ... 3025 3045 3051]
#
# prune_after_accuracy:
#  [0.82109017 0.82109017 0.82109017 ... 0.82109017 0.82109017 0.82109017]

# %%
draw_accuracy_plot(prune_after_accuracy)

# %%
Softmax = prune_after_accuracy

# %% [markdown]
# # AnnealingSoftmax

# %%
algo_name = 'AnnealingSoftmax'

# %%
result_path = os.path.join('./results', pruning_type, str(block_num), algo_name)
result_path
# Out:
# './results/neuron/5/AnnealingSoftmax'

# %%
counts = np.load(os.path.join(result_path, "counts.npy"))
expected_rewards = np.load(os.path.join(result_path, "expected_rewards.npy"))
prune_order = np.load(os.path.join(result_path, "prune_order.npy"))
prune_after_accuracy = np.load(os.path.join(result_path, "prune_after_accuracy.npy"))

# %%
print("counts:\n {} \n".format(counts))
print("expected_rewards:\n {} \n".format(expected_rewards))
print("prune_order:\n {} \n".format(prune_order))
print("prune_after_accuracy:\n {}".format(prune_after_accuracy))
# Out:
# counts:
#  [4 9 0 ... 3 0 2]
#
# expected_rewards:
#  [0.20888607 0.21821767 0.         ... 0.17828711 0.         0.1717767 ]
#
# prune_order:
#  [1966  593 2444 ... 3063 3067 3070]
#
# prune_after_accuracy:
#  [0.82119205 0.82119205 0.82119205 ... 0.82037697 0.82037697 0.82037697]

# %%
draw_accuracy_plot(prune_after_accuracy)

# %%
AnnealingSoftmax = prune_after_accuracy

# %% [markdown]
# # total

# %%
fig = plt.figure(figsize=(10, 6), dpi=80)
ax = fig.add_subplot(111)
N = len(UCB1)
## necessary variables
ind = np.arange(N)                # the x locations for the groups

# bandits
plt.plot(ind , UCB1 , color="blue", linewidth=2.5, linestyle="-", label="UCB1")
plt.plot(ind , EpsilonGreedy, color="red", linewidth=2.5, linestyle="-", label="Epsilon Greedy")
plt.plot(ind , AnnealingEpsilonGreedy, color="cyan", linewidth=2.5, linestyle="-", label="Annealing Epsilon Greedy")
plt.plot(ind , Softmax, color="purple", linewidth=2.5, linestyle="-", label="Softmax")
plt.plot(ind , AnnealingSoftmax, color="yellow", linewidth=2.5, linestyle="-", label="Annealing Softmax")

# random
plt.plot(ind , Random, color="magenta", linewidth=2.5, linestyle="-", label="Random")

plt.legend(loc = 3)
# plt.axis([0, 25, 0, 1])
plt.xlabel('Number of heads pruned')
plt.ylabel('Accuracy after pruning')
plt.grid(True)
plt.show()
